# %%
# What is langgraph and what is use of langGraph?

# %%
## Search(Documentation) ===> Langchain Agents???

# %%
## Langchina 
## 1. Develop Simple AI Assistant

# %% [markdown]
# ## DAY2

# %%
# RAG 
# 1. Agentic RAG 
# 2. CAG 
# 3. Agents 
# 4. LangGraph(Graph, StateGraph, Condtional Edges, Nodes, Edges)

# %%
## LangGRPAH ==>

# %%
# React --> Reasoning and Action
# How to check the codebase of Langraph ===> langgraph github
# check the import statement
#Lib/langraph/graph/(message.py or state.py)

# %%
## Langraph --> is used for orcestration 
# 1. to create workflow 
# 2. to create pipeline

# %%
### AGENTS 
# 2. smart AI Assistants ==> LLM which can take action

# %%
## LLM ==-> is brain 
## ACTION --> is tool calling

# %%
### LangGraph 
# 1. Add Single Tool 
# 2. Add Multiple Tool
# 3. To get the ouput from all the tools ( which is being called)

# %%
## Langchain OpenChatAI -- api reference 
## 1. check bind_tools()

# %% [markdown]
# ## **DAY3**

# %%
# 1. LangGraph --> Memory Save, Human in loop
# 2. Multi Agents

# %%
## Tavily API KEY 
## Search ==> TAVILY
##
## ENV_VARIABLE ==>

# %% [markdown]
# ## **Question**

# %%
#Q) Wheather we should call multiagent vs multiple tools?
#Q) Human Loop (Custom vs Inbuilt Human Loop?)
#Q) What is usecase for inruppting the Human in Loop?
#Q)

# %% [markdown]
# ## **DAY4**

# %%
# Multi Agent

# %%
## Lang Chain 
'''
 1. Data Loader 
 2. Data Splitter
 3. VDB Integration
 4. ChatModel 
 5. Embedding
 6. Prompting 
 7. Parser 
 8. LCEL ==> CHining
'''
## LangChain is also giving the classes to create Agentic FLow , but LangGraph is advance one.

# %%
## LangGraph 
'''
 --> meant to create Agentic FLOW 
 * LLM --> TOOLS 
'''
## AGENTIC FLOW 
'''
 * THIKING --> ACTIOn --> OBSERVATIOn 
 * LLM     --> BRAIN 
 * ACTION --> TOOLS  
'''

### Brain is giving instuctin , Hand is din its task

# %%
## Function -> Nodes, Edges
## GRAPH 
 # Node1 
 # Node2
 # Node3

# %%
## Multi Agent Type 
# 1. Network Agent or Collabrative Agent 
# 2. Supervisor Agent
# 3. Hierachical Agent 
# 4. Custom Agent

# %%
# Type Hinting

# %%
### Architect Interview 
# 1. CLOUD
# 2. one project using CLOUD ( Design , Develop, Deploy)
# 3. Fine Tuning LLM 
# 4. RAG 
# 5. Multi Model RAG 
# 6. Agentic AI

# %%
## DUCK DUCK GO --> SEARCH TOOL

# %%
## Doctor Appointment ===> END To END PRoject
