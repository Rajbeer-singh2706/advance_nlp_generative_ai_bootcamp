# %%
########### GRAPH RAG ###########

# %%
### AGENDA #####

## RAG 
# 1. Data INgestion ---> Database --> VEctorDB(Similarity Search)
# 2. Data REtriver 
# 3. Data GEneration

# %%
### GRAPH DB 
# Store the data in graphdb as well
# Graph Rag Microsoft Research Paper -> SEARCH

# %%
## SEARCH 
## Langchain graph RAG (langchain graph documentation)

# %%
# SUNY VIdeo --> GRAPh RAG (Youtube)
