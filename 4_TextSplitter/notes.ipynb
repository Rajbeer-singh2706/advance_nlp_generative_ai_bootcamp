# %%
                #Token LImit
## GPT 3.5 --> 4096 tokens
## GPT 4 --> 8192 tokens
## GPT 5 --> 128000 tokens

# %%
# Model Limitation 
# Fast Retrival 
# Computation Resources
# 4. IMprove the representation Quality

# %%
## Q) WHy Chunking is Required? ######
# 1. Model LImitation
# 2. Handle non-uniform Document Length 
# 3. Improve the representation of data 
#  4. Fast Retrival Since chunk size we can regulate.
#  5. OPtimization of computation resources.

# %%
## Q) What is the ideal chunk size?
# 1. Hyperpameter, 
# 2. I tested with Several chunk size and found 
# Suject to Model , Compuatinal Resources , Data Type

# %%
# Two OPtions 
# 1. Without Chunking 
# 2. with Chunking  (512, 1024, 2048, 4096)

# %%
# Q) What is semantic Chunking ?
# Q) What is the difference between semantic chunking and regular chunking ?
# Q) How the chunking will happen for images ?
# Q) how to chunk NCERT book ?

# %%
## Approaches to Chunking
# 1. Length Based Chunking ( token/Word or character based )
# 2. Text Structure Based Chunking (paragraph,Sentences,  section, chapter based chunking )
# 3. Document Structure Based Chunking (Markdown, HTML,CODE, JSON, XML based chunking )
# 4. Semantic Based Chunking (using embedding and similarity based chunking )
#

# %%
## Search Langchain Documenation for text splitter and read about different text splitter available in langchain.

# %%
# https://docs.langchain.com/oss/python/integrations/splitters

# %%
## Assignment : 
# create a notebook for each text splitter and deveop with 1 example 
# take each & envery text splitter in langchain and apply on different type of data and check the output.
