# %%
"ALLOKAY"
# Out:
# 'ALLOKAY'

# %%
## HuggingFace Embedding Model is used which is free to use ?

# %%
#GROQ      ===> https://console.groq.com/keys
#HG        ===> https://huggingface.co/BAAI/bge-small-en
#LangSmit  ===> https://smith.langchain.com/hub

# %%
# RAG --> Retrieval-Augmented Generation
# RAG is a framework that combines retrieval-based methods with generative models to enhance the performance of natural language processing tasks. It allows models to retrieve relevant information from a large corpus of data and use that information to generate more accurate and contextually relevant responses.

# %%
## 09 MARCH --> RAG Introduction and Implementation ###

# %%
# What is difference b/w Simple AI ASsistent vs RAG 
# Finetuning & RAG 
# Architecture of RAG 
# Implementation of RAG 
# LangChain
# Vector Database
# MultiModel RAG 
# Graph RAG 
# CAG ( Fast REtrival) --> Cache 
# Agentic RAG

# %%
## What is difference b/w Simple AI ASsistent vs RAG 
# RAG COmponents
# 1. Data Ingestion
# 2. Data REtriveer
# 3. Data Generation

# %%
# Data => Pretained Model (LLM) ===> Supervised Finetuning (SFT) ===>RHLF/DPO ===> FInal LLM

# %%
# Prompt is divided into 3 categories
# 1. Zero Shot Prompting
# 2. Few Shot Prompting
# 3. Chain of Thought Prompting(COT)

# %%
## GROQ --> Get model
## GROP API (FREE API )
## Create API KEY

# %%
## Google AI Studio --> GEMINI MODEL

# %%
# pip install <>

# %%
## Chat Groq UI , lot of model are are there use that 
## GROQ API KEY ====>

# %%
# VECTOR Databse ===> FAISS(IN memory Database)

# %%
## Hugging Face ===> for Embedding model

# %%
#Lang Chain Hub ===> for Prompt Template

# %%
## 40000 tokens ===> 1000 tokens ===> 40 documents

# %%
# What is the definition of a Token for Groq API or any LLM?
# What is use of RunnablePassthrough?
