# %%
#### Multi Model RAG ###

# %%
# Agenda
## 1. Pinecone 
## 2. MM RAG 
    ## Data --> Text, Image, Audio/Video, Table

# %%
## VECTOR DB Comparision ==> DOCS

# %%
# is there any libraru which can check what is optimal value for chunk size instead we check manully

# %% [markdown]
# ## **PINECONE**

# %%
## Search ==> Pinecode API KEY

# %%
## Two ways to insert data
### 1. using pinecode library
### 2. Cheeck with Langchain wrapper
