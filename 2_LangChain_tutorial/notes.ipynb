# %%
"ALLOKAY"
# Out:
# 'ALLOKAY'

# %%
## URL : 
## https://developers.openai.com/api/docs/models/all
## https://docs.langchain.com/oss/python/deepagents/overview

# %% [markdown]
# ## **INTRODCUTION**

# %%
## Frameworks for Building LLM Applications
## LangChain Framework (Understand this well , rest are same)
## HayStack Framework(SImilar to langchain)
## LLamaIndex Framework(Similar to langchain)

# %%
## LANGCHAIN FRAMEWORK
'''
  * LangChain
  * LangGraph
  * LangFlow 
  * LangSmith
'''

# %%
######## AGENDA ##########
# LangChain Framework
## 1. ChatModel 
## 2. EmbeddingModel 
## 3. Parser 
## 4. PromptTemplate
## 5. Chaining 
## 6. Agents(LangGraph)
## 7. Text Splitter(Chunking)

# %%
## Langchain ==> Docs

# %%
#### SIMILARITY Search  #####
## KNN(K-Nearest Neighbour)
## MMR(Maximal Marginal Relevance) 
## Cosine Similarity

# %%
## LangChain Docs ==> Integrations with different Models

# %% [markdown]
# ## **API KEY**

# %%
## GOOGLE AI STUDIO 
## URL : https://aistudio.google.com/
'''
  * to create API KEY , to access gemini model 
'''

# %%
## OPEN AI 
## URL : https://platform.openai.com/
'''
  * to create API KEY , to access GPT Model 
'''

# %%
## GROQ API  
## URL : 
'''
  * to create API KEY , to access groq Model 
'''

# %%
## Huggine Face API  
## URL : 
'''
  * to generate a token for accessing Hugging Face models
'''

# %%
## CLAUDE API KEY 
## URL : 
'''
  * to create API KEY , to access Claude Model 
'''

# %% [markdown]
# ## **ChatModels**

# %%
## 1. Groq 
## 2. GOOGLE 
## 3. OPENAI 
## 4. HUGGING FACE
## 5. CLAUDE
## 6. DEepSeek

## U can call or create model from their respective vendor 
## but with langchain Wrapper u can call same set of methods to interact with different models from different vendors without changing your code much

# %% [markdown]
# ## **Embedding Model**

# %%
# What is Embedding Model ?

# %%
## Search ==> OPEN AI Models

# %%
## Model Provided by different vendors to convert text data into vector representation (Numerical Format) which can be used for various downstream tasks like similarity search, clustering, classification etc.
## OPENAI ==> text-embedding-3-small , text-embedding-3-large (Text)
## GOOGLE ==> gemini-embedding-3-small , gemini-embedding-3-large

# %%
## OPENAI also provides smaller embedding model which is faster and cheaper 
# than large embedding model but with slightly less accuracy. We can use 
# that for simple use cases where we don't need very high accuracy and want to save cost and time.

# %%
#OpenAIEmbeddings
'''
  * embed_query() ==> to convert query into vector representation
  * embed_documents() ==> to convert list of documents into vector representation
'''

# %%
## Perform Consine Similarity Search using OPENAI Embedding Model

# %% [markdown]
# ## **PROMPT**

# %%
# Q) What is difference between PromptTemplate Vs ChatPromptTemplate

# %%
# PromptTemplate/ChatPromptTempalte
## invoke()

# %%
# Prompt Library 
# Langchain HUB

# %%
# what is System Message?

# %%
# 1. PromptTemplate
# 2. ChatPromptTemplate

# %%
# System_Message: Setting the context to the model
# HumanMessage: User input to the model
# AIMessage: Model Generated Answer

# %%
## Flow CV --> to create resume

# %% [markdown]
# ## **Chaining**

# %%
# Chain ==> connect different components together to perform a specific task
# 1. Prompt 
# 2. LLM 
# 3. Parser 

## LCEL ==> LangChain Expression Language
## Docs ===> LangChain Documentation ==> chain

# %%
###### CHAINS ###########
# 1. Simple Chain
# 2. Sequential Chain
# 3. Parallel Chain

# %% [markdown]
# ## **Parser**

# %%
# Parser ==> parse the data 
# Convert the data according to our Requirement

# %%
# from langchain_core.output_parsers import JsonOutputParser
# 1. STROutputParser
# 2. JsonOutputParser
# 3. StructuredOutputParser
# 4. PydanticOutputParser : to parse the output into pydantic model
        # ## 1. Validate the response as per the defined schema
        # ## 2. Parse the response into desired format

# %%
# Real time Vector Database ---> CLOUD Based
