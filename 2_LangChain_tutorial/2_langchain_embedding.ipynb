# %%
"ALLOKAY"
# Out:
# 'ALLOKAY'

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
### Chat Model Wrappers
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
#from langchain_anthropic import ChatAnthropic
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %% [markdown]
# # **Embedding Models**

# %%
# Transformer Based Embedding Models
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# ### **Create embedding Model**

# %%
## Large Model 
## Need API KEY 
embeddings=OpenAIEmbeddings(model='text-embedding-3-large')

# %%
# 2. Hugging Face Embedding Model
from langchain_huggingface import HuggingFaceEmbeddings

embeddings=HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)

# %%
result=embeddings.embed_query("India is a growing country")

# %%
len(result)
## Dimesion : 3072
# Out:
# 3072

# %%
# 2. OPENAI ==> text-embedding-3-small 
embeddings=OpenAIEmbeddings(model='text-embedding-3-small')

# %%
result2=embeddings.embed_query("India is a growing country")

# %%
## Dimension 
len(result2)
# Out:
# 1536

# %%
# Regulate the dimension of embedding vector
embeddings=OpenAIEmbeddings(
    model='text-embedding-3-large',
    dimensions=64
)

# %%
result3=embeddings.embed_query("India is a growing country")

# %%
len(result3)
# Out:
# 64

# %%
documents=["what is a capital of USA",
           "who is a president of usa",
           "who is a prime minister of india"]

# %%
result=embeddings.embed_documents(documents)

# %%
len(result)
# Out:
# 3

# %%
len(result[0])

# %%
result[0]
# Out:
# [-0.0723918005824089,
#  0.15564556419849396,
#  -0.009400391951203346,
#  0.11175045371055603,
#  -0.1681687831878662,
#  -0.05012477561831474,
#  0.09993007779121399,
#  0.11871489137411118,
#  -0.20228812098503113,
#  -0.019200120121240616,
#  -0.029007835313677788,
#  0.12012055516242981,
#  -0.19321519136428833,
#  -0.3414490520954132,
#  0.0063095237128436565,
#  -0.025014465674757957,
#  -0.2385798692703247,
#  0.2573646903038025,
#  0.14107775688171387,
#  0.1100253164768219,
#  0.11730922013521194,
#  0.05446955934166908,
#  -0.08012296259403229,
#  0.014775467105209827,
#  -0.013401747681200504,
#  0.02817721478641033,
#  0.08172031491994858,
#  -0.004780063405632973,
#  0.09571307897567749,
#  0.08459553867578506,
#  0.1895093470811844,
#  0.07584207504987717,
#  0.19462086260318756,
#  -0.13027969002723694,
#  0.0063454643823206425,
#  0.08312597870826721,
#  0.04485352709889412,
#  0.010718204081058502,
#  -0.05325557664036751,
#  0.09890777617692947,
# ...

# %% [markdown]
# ## **consine Similarity Search**

# %%
documents=["what is a capital of USA",
           "who is a president of usa",
           "who is a prime minister of india"]

my_query="narendra modi is indian prime minister"

# %%
query_embedding=embeddings.embed_query(my_query)
document_embedding=embeddings.embed_documents(documents)

# %%
document_embedding
# Out:
# [[-0.0723918005824089,
#   0.15564556419849396,
#   -0.009400391951203346,
#   0.11175045371055603,
#   -0.1681687831878662,
#   -0.05012477561831474,
#   0.09993007779121399,
#   0.11871489137411118,
#   -0.20228812098503113,
#   -0.019200120121240616,
#   -0.029007835313677788,
#   0.12012055516242981,
#   -0.19321519136428833,
#   -0.3414490520954132,
#   0.0063095237128436565,
#   -0.025014465674757957,
#   -0.2385798692703247,
#   0.2573646903038025,
#   0.14107775688171387,
#   0.1100253164768219,
#   0.11730922013521194,
#   0.05446955934166908,
#   -0.08012296259403229,
#   0.014775467105209827,
#   -0.013401747681200504,
#   0.02817721478641033,
#   0.08172031491994858,
#   -0.004780063405632973,
#   0.09571307897567749,
#   0.08459553867578506,
#   0.1895093470811844,
#   0.07584207504987717,
#   0.19462086260318756,
#   -0.13027969002723694,
#   0.0063454643823206425,
#   0.08312597870826721,
#   0.04485352709889412,
#   0.010718204081058502,
#   -0.05325557664036751,
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
scores=cosine_similarity([query_embedding],document_embedding)

# %%
scores
## 69% similary to 3rd document which is correct answer.(0.69040144)
# Out:
# array([[0.13453207, 0.38540264, 0.69040144]])

# %% [markdown]
# ## **Google Gemini Embedding Model**

# %%
# 3. Google Gemini Embedding Model
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001"
)
