# %%
# How to load multiple pdf files ?

# %%
## if u want to use embedding model from hugging face , please check old video

# %%
### VECTOR DATABASE ###
## Chroma DB

# %%
## langchain opensearch vector database DOcumentation

# %% [markdown]
# Good, I have all the context I need. Let me build the Lecture 19 PDF:Here's your **Vector Database — Lecture 19 PDF**! Here's what's packed inside:
#
# - **Custom dark-themed cover page** with a teal/yellow/orange palette matching the VDB theme, and all 10 topic previews
# - **10 fully expanded chapters** covering every concept from your notes:
#   - What a vector is, with an illustrated 2D vector plot
#   - SQL vs NoSQL vs Vector DB comparison table
#   - Why SQL can't do similarity search (with a feature matrix)
#   - Core Vector DB operations pipeline diagram
#   - All 4 indexing methods (Flat, IVF, HNSW, LSH) with deep explanations
#   - All 4 similarity metrics (Cosine, Dot Product, MMR, Euclidean L2)
#   - ANN vs Exact Search comparison
#   - IVF deep dive with a cluster diagram and nlist/nprobe parameter table
#   - FAISS architecture, limitations, and comparison with managed vector DBs
#   - Advanced RAG topics overview (Agentic, Graph, Multimodal, CAG)
# - **Styled consistently** with Lecture 18 — same format, new color schemeGood, I have all the context I need. Let me build the Lecture 19 PDF:Here's your **Vector Database — Lecture 19 PDF**! Here's what's packed inside:
#
# - **Custom dark-themed cover page** with a teal/yellow/orange palette matching the VDB theme, and all 10 topic previews
# - **10 fully expanded chapters** covering every concept from your notes:
#   - What a vector is, with an illustrated 2D vector plot
#   - SQL vs NoSQL vs Vector DB comparison table
#   - Why SQL can't do similarity search (with a feature matrix)
#   - Core Vector DB operations pipeline diagram
#   - All 4 indexing methods (Flat, IVF, HNSW, LSH) with deep explanations
#   - All 4 similarity metrics (Cosine, Dot Product, MMR, Euclidean L2)
#   - ANN vs Exact Search comparison
#   - IVF deep dive with a cluster diagram and nlist/nprobe parameter table
#   - FAISS architecture, limitations, and comparison with managed vector DBs
#   - Advanced RAG topics overview (Agentic, Graph, Multimodal, CAG)
# - **Styled consistently** with Lecture 18 — same format, new color scheme
