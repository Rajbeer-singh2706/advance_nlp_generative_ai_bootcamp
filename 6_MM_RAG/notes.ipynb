# %% [markdown]
# Here's your **Multimodal RAG — Lecture 21 PDF**! Here's what's inside across 10 chapters:
#
# - **Dark purple/pink/cyan cover page** with all 10 topic previews, consistent with Lectures 18 & 19
# - **MMRAG Overview** — tools comparison: FAISS (in-memory) vs ChromaDB (disk) vs Pinecone (cloud)
# - **Multimodal Data Types** — Text, Image, Table, Audio, Video with extraction methods and embedding strategies
# - **Full MMRAG Pipeline diagram** — 8-stage flow from raw document to LLM response
# - **Document Parsing Libraries** — python-docx, PyPDF, PyMuPDF, pdfplumber, Camelot, Unstructured — all compared
# - **LangChain + Unstructured integration** — code patterns and element types (NarrativeText, Table, Image)
# - **Document Object explained** — page_content vs metadata, with examples for each modality
# - **Summarisation strategy** — how Text/Table/Image summaries are generated and why
# - **Vector DB schema** — cylinder diagram showing how all 3 modality types coexist in one VDB
# - **End-to-end 16-step pipeline table** — complete ingestion → retrieval → generation walkthrough

# %%
## unstructure io documentation

# %%
## docx libraru --->

# %%
## Test MUlti Model with 
 # 1. OPENAI ---> u will get good results 
 # 2. GroqAI
 # 3. Google Gemini

# %% [markdown]
# ## **QUestions**

# %%
#Q) For Query are u doing the embedding?
#Q) What is RAG ?
#Q) What is Multi model RAG?
#Q) What is REtriver
